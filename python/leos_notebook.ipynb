# %%
import pandas as pd

county_sales_csv = "resources/Cannabis_Sales_By_County.csv"
census_pop_csv = "resources/Census_pop.csv"
county_per_cap_income_csv = "resources/County Per capita income.csv"
retail_licenses_csv = "resources/retail-licenses.csv"

# %%
county_sales_df = pd.read_csv(county_sales_csv)
census_pop_df = pd.read_csv(census_pop_csv)
county_per_cap_income_df = pd.read_csv(county_per_cap_income_csv)
retail_licenses_df = pd.read_csv(retail_licenses_csv)


county_sales_df
# Out:
#          County Month Filter  Latitude (generated)  Longitude (generated)  \
# 0       Klamath     1/1/2019               42.8067              -121.8166
# 1         Grant     1/1/2019               44.4798              -119.0090
# 2          Lake     1/1/2019               42.8178              -120.6468
# 3        Harney     1/1/2019               43.0263              -119.0802
# 4     Jefferson     1/1/2019               44.6083              -121.0936
# ..          ...          ...                   ...                    ...
# 721      Marion    12/1/2020               44.9852              -122.8053
# 722     Malheur    12/1/2020               43.2329              -117.6274
# 723        Lane    12/1/2020               43.8651              -122.7483
# 724  Washington    12/1/2020               45.5492              -123.1040
# 725   Multnomah    12/1/2020               45.5805              -122.6646
#
#            Sales
# 0       28029.69
# 1       60853.20
# 2       80451.52
# 3       89863.24
# 4      262448.04
# ..           ...
# 721   6551116.36
# 722   8582260.43
# 723   8767494.80
# 724   9481939.83
# 725  26784330.92
#
# [726 rows x 5 columns]

# %%
census_pop_df
# Out:
#                 Geographic Area  Census Estimates Base    2010    2011  \
# 0       Abbeville city, Alabama   2,688          2,705   2,699   2,694
# 1      Adamsville city, Alabama   4,522          4,506   4,500   4,493
# 2         Addison town, Alabama     758            754     751     750
# 3           Akron town, Alabama     356            356     355     347
# 4       Alabaster city, Alabama  30,352         31,112  31,209  31,375
# ...                         ...     ...            ...     ...     ...
# 19497   Wamsutter town, Wyoming     451            451     450     453
# 19498   Wheatland town, Wyoming   3,627          3,625   3,622   3,620
# 19499     Worland city, Wyoming   5,487          5,487   5,487   5,436
# 19500      Wright town, Wyoming   1,807          1,807   1,810   1,812
# 19501       Yoder town, Wyoming     151            151     152     153
#
#          2012    2013    2014    2015    2016    2017    2018    2019
# 0       2,643   2,628   2,608   2,600   2,584   2,575   2,571   2,560
# 1       4,471   4,449   4,420   4,390   4,356   4,327   4,308   4,281
# 2         743     742     739     734     731     726     723     718
# 3         347     343     338     339     333     332     331     328
# 4      31,684  31,980  32,182  32,772  33,017  33,275  33,413  33,487
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 19497     462     487     508     499     493     483     474     467
# 19498   3,626   3,622   3,642   3,645   3,587   3,549   3,527   3,462
# 19499   5,419   5,419   5,328   5,332   5,263   5,158   5,071   5,024
# 19500   1,864   1,860   1,856   1,885   1,857   1,760   1,754   1,753
# 19501     154     157     159     159     156     156     155     154
#
# [19502 rows x 13 columns]

# %%
oregon_city_pop = census_pop_df.loc[census_pop_df["Geographic Area"].str.endswith("Oregon"), ["Geographic Area", "Census", "2019"]].reset_index(drop=True)
oregon_city_pop = oregon_city_pop.rename(columns={"Census": "2020"})
oregon_city_pop
# Out:
#                 Geographic Area    2020    2019
# 0    Adair Village city, Oregon     840     874
# 1            Adams city, Oregon     350     357
# 2           Adrian city, Oregon     177     173
# 3           Albany city, Oregon  50,158  55,338
# 4            Amity city, Oregon   1,614   1,724
# ..                          ...     ...     ...
# 235       Woodburn city, Oregon  24,080  26,273
# 236   Wood Village city, Oregon   3,878   4,093
# 237        Yachats city, Oregon     690     784
# 238        Yamhill city, Oregon   1,024   1,169
# 239       Yoncalla city, Oregon   1,047   1,096
#
# [240 rows x 3 columns]

# %%
county_per_cap_income_df
# Out:
#             County  Personal income (thousands of dollars)  Population  \
# 0        Baker, OR                                  685166       16124
# 1       Benton, OR                                 4534024       93053
# 2    Clackamas, OR                                25812808      418187
# 3      Clatsop, OR                                 1893791       40224
# 4     Columbia, OR                                 2409293       52354
# 5         Coos, OR                                 2994046       64487
# 6        Crook, OR                                 1039221       24404
# 7        Curry, OR                                 1042502       22925
# 8    Deschutes, OR                                11159204      197692
# 9      Douglas, OR                                 4698282      110980
# 10     Gilliam, OR                                  105942        1912
# 11       Grant, OR                                  308754        7199
# 12      Harney, OR                                  309164        7393
# 13  Hood River, OR                                 1316983       23382
# 14     Jackson, OR                                10669698      220944
# 15   Jefferson, OR                                  866858       24658
# 16   Josephine, OR                                 3810451       87487
# 17     Klamath, OR                                 2839572       68238
# 18        Lake, OR                                  340162        7869
# 19        Lane, OR                                18087217      382067
# 20     Lincoln, OR                                 2294997       49962
# 21        Linn, OR                                 5816653      129749
# 22     Malheur, OR                                 1057034       30571
# 23      Marion, OR                                15706672      347818
# 24      Morrow, OR                                  563965       11603
# 25   Multnomah, OR                                49399774      812855
# 26        Polk, OR                                 3692806       86085
# 27     Sherman, OR                                  101353        1780
# 28   Tillamook, OR                                 1240385       27036
# 29    Umatilla, OR                                 3268316       77950
# 30       Union, OR                                 1119594       26835
# 31     Wallowa, OR                                  331884        7208
# 32       Wasco, OR                                 1163239       26682
# 33  Washington, OR                                38527576      601592
# 34     Wheeler, OR                                   52438        1332
# 35     Yamhill, OR                                 5086605      107100
#
#     Per capita income ($)
# 0                   42494
# 1                   48725
# 2                   61726
# 3                   47081
# 4                   46019
# 5                   46429
# 6                   42584
# 7                   45474
# 8                   56447
# 9                   42334
# 10                  55409
# 11                  42888
# 12                  41818
# 13                  56325
# 14                  48291
# 15                  35155
# 16                  43554
# 17                  41613
# 18                  43228
# 19                  47340
# 20                  45935
# 21                  44830
# 22                  34576
# 23                  45158
# 24                  48605
# 25                  60773
# 26                  42897
# 27                  56940
# 28                  45879
# 29                  41928
# 30                  41721
# 31                  46044
# 32                  43596
# 33                  64043
# 34                  39368
# 35                  47494

# %%
for index, row in county_per_cap_income_df.iterrows():
    county_name = row["County"].split(", ")[0]
    
    county_per_cap_income_df.loc[index, "County"] = county_name
    
county_per_cap_income_df
# Out:
#         County  Personal income (thousands of dollars)  Population  \
# 0        Baker                                  685166       16124
# 1       Benton                                 4534024       93053
# 2    Clackamas                                25812808      418187
# 3      Clatsop                                 1893791       40224
# 4     Columbia                                 2409293       52354
# 5         Coos                                 2994046       64487
# 6        Crook                                 1039221       24404
# 7        Curry                                 1042502       22925
# 8    Deschutes                                11159204      197692
# 9      Douglas                                 4698282      110980
# 10     Gilliam                                  105942        1912
# 11       Grant                                  308754        7199
# 12      Harney                                  309164        7393
# 13  Hood River                                 1316983       23382
# 14     Jackson                                10669698      220944
# 15   Jefferson                                  866858       24658
# 16   Josephine                                 3810451       87487
# 17     Klamath                                 2839572       68238
# 18        Lake                                  340162        7869
# 19        Lane                                18087217      382067
# 20     Lincoln                                 2294997       49962
# 21        Linn                                 5816653      129749
# 22     Malheur                                 1057034       30571
# 23      Marion                                15706672      347818
# 24      Morrow                                  563965       11603
# 25   Multnomah                                49399774      812855
# 26        Polk                                 3692806       86085
# 27     Sherman                                  101353        1780
# 28   Tillamook                                 1240385       27036
# 29    Umatilla                                 3268316       77950
# 30       Union                                 1119594       26835
# 31     Wallowa                                  331884        7208
# 32       Wasco                                 1163239       26682
# 33  Washington                                38527576      601592
# 34     Wheeler                                   52438        1332
# 35     Yamhill                                 5086605      107100
#
#     Per capita income ($)
# 0                   42494
# 1                   48725
# 2                   61726
# 3                   47081
# 4                   46019
# 5                   46429
# 6                   42584
# 7                   45474
# 8                   56447
# 9                   42334
# 10                  55409
# 11                  42888
# 12                  41818
# 13                  56325
# 14                  48291
# 15                  35155
# 16                  43554
# 17                  41613
# 18                  43228
# 19                  47340
# 20                  45935
# 21                  44830
# 22                  34576
# 23                  45158
# 24                  48605
# 25                  60773
# 26                  42897
# 27                  56940
# 28                  45879
# 29                  41928
# 30                  41721
# 31                  46044
# 32                  43596
# 33                  64043
# 34                  39368
# 35                  47494

# %%
retail_licenses_df
# Out:
#                         TRADE NAME POSTAL CITY   COUNTY  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                         STREET ADDRESS    ZIP Med Grade Delivery
# 0               210 W. WASHINGTON ST.   97907       NaN      NaN
# 1                 120 E WASHINGTON ST   97907       Yes      NaN
# 2      160 N. MILL STREET, SUITE #102   97877       Yes      NaN
# 3    363 B SOUTH MILL STREET PO BOX 74  97877       NaN      NaN
# 4                    126 SW AVERY AVE   97333       NaN      NaN
# ..                                 ...    ...       ...      ...
# 732      2316 E PORTLAND RD SUITE C-2   97132       Yes      NaN
# 733         308 VILLA ROAD, SUITE 115   97132       Yes      Yes
# 734           1013 N. SPRINGBROOK RD.   97132       Yes      Yes
# 735                    1210 W MAIN ST   97378       Yes      NaN
# 736              950 SE SHERIDAN ROAD   97378       Yes      Yes
#
# [737 rows x 7 columns]

# %%
retail_licenses_df["COUNTY"].unique()
# Out:
# array(['BAKER', 'BENTON', 'CLACKAMAS', 'CLATSOP', 'COLUMBIA', 'COOS',
#        'CURRY', 'DESCHUTES', 'DOUGLAS', 'KLAMATH', 'GRANT', 'WALLOWA',
#        'MALHEUR', 'HARNEY', 'HOOD RIVER', 'JACKSON', 'JEFFERSON',
#        'JOSEPHINE', 'LAKE', 'LANE', 'LINCOLN', 'LINN', 'MARION',
#        'MULTNOMAH', 'POLK', 'TILLAMOOK', 'UMATILLA', 'WASCO',
#        'WASHINGTON', 'YAMHILL'], dtype=object)

# %%
dispo_by_county = retail_licenses_df.groupby("COUNTY").agg({"TRADE NAME": "count"}).reset_index(drop=False).rename(columns={"COUNTY": "County", "TRADE NAME": "Dispensary Count"})
dispo_by_county["County"] = dispo_by_county["County"].str.title()
dispo_by_county
# Out:
#         County  Dispensary Count
# 0        Baker                 4
# 1       Benton                15
# 2    Clackamas                30
# 3      Clatsop                19
# 4     Columbia                11
# 5         Coos                24
# 6        Curry                11
# 7    Deschutes                30
# 8      Douglas                16
# 9        Grant                 1
# 10      Harney                 2
# 11  Hood River                 6
# 12     Jackson                48
# 13   Jefferson                 5
# 14   Josephine                11
# 15     Klamath                 5
# 16        Lake                 2
# 17        Lane                82
# 18     Lincoln                24
# 19        Linn                21
# 20     Malheur                 9
# 21      Marion                61
# 22   Multnomah               216
# 23        Polk                11
# 24   Tillamook                11
# 25    Umatilla                 4
# 26     Wallowa                 1
# 27       Wasco                 5
# 28  Washington                40
# 29     Yamhill                12

# %%
first_merge = county_per_cap_income_df.merge(dispo_by_county, on="County", how="outer")

# %%
county_clean_merge = first_merge.dropna().reset_index(drop=True)
county_clean_merge
# Out:
#         County  Personal income (thousands of dollars)  Population  \
# 0        Baker                                  685166       16124
# 1       Benton                                 4534024       93053
# 2    Clackamas                                25812808      418187
# 3      Clatsop                                 1893791       40224
# 4     Columbia                                 2409293       52354
# 5         Coos                                 2994046       64487
# 6        Curry                                 1042502       22925
# 7    Deschutes                                11159204      197692
# 8      Douglas                                 4698282      110980
# 9        Grant                                  308754        7199
# 10      Harney                                  309164        7393
# 11  Hood River                                 1316983       23382
# 12     Jackson                                10669698      220944
# 13   Jefferson                                  866858       24658
# 14   Josephine                                 3810451       87487
# 15     Klamath                                 2839572       68238
# 16        Lake                                  340162        7869
# 17        Lane                                18087217      382067
# 18     Lincoln                                 2294997       49962
# 19        Linn                                 5816653      129749
# 20     Malheur                                 1057034       30571
# 21      Marion                                15706672      347818
# 22   Multnomah                                49399774      812855
# 23        Polk                                 3692806       86085
# 24   Tillamook                                 1240385       27036
# 25    Umatilla                                 3268316       77950
# 26     Wallowa                                  331884        7208
# 27       Wasco                                 1163239       26682
# 28  Washington                                38527576      601592
# 29     Yamhill                                 5086605      107100
#
#     Per capita income ($)  Dispensary Count
# 0                   42494               4.0
# 1                   48725              15.0
# 2                   61726              30.0
# 3                   47081              19.0
# 4                   46019              11.0
# 5                   46429              24.0
# 6                   45474              11.0
# 7                   56447              30.0
# 8                   42334              16.0
# 9                   42888               1.0
# 10                  41818               2.0
# 11                  56325               6.0
# 12                  48291              48.0
# 13                  35155               5.0
# 14                  43554              11.0
# 15                  41613               5.0
# 16                  43228               2.0
# 17                  47340              82.0
# 18                  45935              24.0
# 19                  44830              21.0
# 20                  34576               9.0
# 21                  45158              61.0
# 22                  60773             216.0
# 23                  42897              11.0
# 24                  45879              11.0
# 25                  41928               4.0
# 26                  46044               1.0
# 27                  43596               5.0
# 28                  64043              40.0
# 29                  47494              12.0

# %%
sorted_county = county_clean_merge.sort_values("Personal income (thousands of dollars)", ascending=False)
sorted_county["Population per Dispenary"] = round(sorted_county["Population"] / sorted_county["Dispensary Count"], 0)
sorted_county
# Out:
#         County  Personal income (thousands of dollars)  Population  \
# 22   Multnomah                                49399774      812855
# 28  Washington                                38527576      601592
# 2    Clackamas                                25812808      418187
# 17        Lane                                18087217      382067
# 21      Marion                                15706672      347818
# 7    Deschutes                                11159204      197692
# 12     Jackson                                10669698      220944
# 19        Linn                                 5816653      129749
# 29     Yamhill                                 5086605      107100
# 8      Douglas                                 4698282      110980
# 1       Benton                                 4534024       93053
# 14   Josephine                                 3810451       87487
# 23        Polk                                 3692806       86085
# 25    Umatilla                                 3268316       77950
# 5         Coos                                 2994046       64487
# 15     Klamath                                 2839572       68238
# 4     Columbia                                 2409293       52354
# 18     Lincoln                                 2294997       49962
# 3      Clatsop                                 1893791       40224
# 11  Hood River                                 1316983       23382
# 24   Tillamook                                 1240385       27036
# 27       Wasco                                 1163239       26682
# 20     Malheur                                 1057034       30571
# 6        Curry                                 1042502       22925
# 13   Jefferson                                  866858       24658
# 0        Baker                                  685166       16124
# 16        Lake                                  340162        7869
# 26     Wallowa                                  331884        7208
# 10      Harney                                  309164        7393
# 9        Grant                                  308754        7199
#
#     Per capita income ($)  Dispensary Count  Population per Dispenary
# 22                  60773             216.0                    3763.0
# 28                  64043              40.0                   15040.0
# 2                   61726              30.0                   13940.0
# 17                  47340              82.0                    4659.0
# 21                  45158              61.0                    5702.0
# 7                   56447              30.0                    6590.0
# 12                  48291              48.0                    4603.0
# 19                  44830              21.0                    6179.0
# 29                  47494              12.0                    8925.0
# 8                   42334              16.0                    6936.0
# 1                   48725              15.0                    6204.0
# 14                  43554              11.0                    7953.0
# 23                  42897              11.0                    7826.0
# 25                  41928               4.0                   19488.0
# 5                   46429              24.0                    2687.0
# 15                  41613               5.0                   13648.0
# 4                   46019              11.0                    4759.0
# 18                  45935              24.0                    2082.0
# 3                   47081              19.0                    2117.0
# 11                  56325               6.0                    3897.0
# 24                  45879              11.0                    2458.0
# 27                  43596               5.0                    5336.0
# 20                  34576               9.0                    3397.0
# 6                   45474              11.0                    2084.0
# 13                  35155               5.0                    4932.0
# 0                   42494               4.0                    4031.0
# 16                  43228               2.0                    3934.0
# 26                  46044               1.0                    7208.0
# 10                  41818               2.0                    3696.0
# 9                   42888               1.0                    7199.0

# %%
print(len(county_per_cap_income_df))
print(len(dispo_by_county))
# Out:
# 36
# 30

# %%
first_set = set(county_per_cap_income_df["County"])
second_set = set(dispo_by_county["County"])
print(first_set - second_set)
# Out:
# {'Gilliam', 'Morrow', 'Union', 'Wheeler', 'Crook', 'Sherman'}
