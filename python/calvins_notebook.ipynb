# %%
import pandas as pd

county_sales_csv = "resources/Cannabis_Sales_By_County.csv"
census_pop_csv = "resources/Census_pop.csv"
county_per_cap_income_csv = "resources/County Per capita income.csv"
retail_licenses_csv = "resources/retail-licenses.csv"
from googlemaps import Client as GoogleMaps

gmaps = GoogleMaps('AIzaSyCicQiT6YEFK7UZJDUND0avjswnr9jgwQA')

# %%
county_sales_df = pd.read_csv(county_sales_csv)
census_pop_df = pd.read_csv(census_pop_csv)
county_per_cap_income_df = pd.read_csv(county_per_cap_income_csv)
retail_licenses_df = pd.read_csv(retail_licenses_csv)

# %%
oregon_city_pop = census_pop_df.loc[census_pop_df["Geographic Area"].str.endswith("Oregon"), ["Geographic Area", "Census", "2019"]].reset_index(drop=True)
oregon_city_pop = oregon_city_pop.rename(columns={"Census": "2020"})
oregon_city_pop
# Out:
#                 Geographic Area    2020    2019
# 0    Adair Village city, Oregon     840     874
# 1            Adams city, Oregon     350     357
# 2           Adrian city, Oregon     177     173
# 3           Albany city, Oregon  50,158  55,338
# 4            Amity city, Oregon   1,614   1,724
# ..                          ...     ...     ...
# 235       Woodburn city, Oregon  24,080  26,273
# 236   Wood Village city, Oregon   3,878   4,093
# 237        Yachats city, Oregon     690     784
# 238        Yamhill city, Oregon   1,024   1,169
# 239       Yoncalla city, Oregon   1,047   1,096
#
# [240 rows x 3 columns]

# %%
oregon_city_pop['long'] = ""
oregon_city_pop['lat'] = ""

# %%
oregon_city_pop
# Out:
#                 Geographic Area    2020    2019 long lat
# 0    Adair Village city, Oregon     840     874
# 1            Adams city, Oregon     350     357
# 2           Adrian city, Oregon     177     173
# 3           Albany city, Oregon  50,158  55,338
# 4            Amity city, Oregon   1,614   1,724
# ..                          ...     ...     ...  ...  ..
# 235       Woodburn city, Oregon  24,080  26,273
# 236   Wood Village city, Oregon   3,878   4,093
# 237        Yachats city, Oregon     690     784
# 238        Yamhill city, Oregon   1,024   1,169
# 239       Yoncalla city, Oregon   1,047   1,096
#
# [240 rows x 5 columns]

# %%
for x in range(len(oregon_city_pop)):
    try:
        geocode_result = gmaps.geocode(oregon_city_pop['Geographic Area'][x])
        oregon_city_pop['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        oregon_city_pop['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
oregon_city_pop.head()
# Out:
# Unexpected error occurred. REQUEST_DENIED (An internal error was found for this API project.)
#               Geographic Area    2020    2019     long      lat
# 0  Adair Village city, Oregon     840     874 -123.218  44.6707
# 1          Adams city, Oregon     350     357 -118.562  45.7674
# 2         Adrian city, Oregon     177     173 -117.072  43.7407
# 3         Albany city, Oregon  50,158  55,338 -123.106  44.6365
# 4          Amity city, Oregon   1,614   1,724 -123.207  45.1157

# %%
# oregon_city_pop.to_csv(r'output\cityLatLong.csv', index = False)

# %%
retail_licenses_df
# Out:
#                         TRADE NAME POSTAL CITY   COUNTY  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                         STREET ADDRESS    ZIP Med Grade Delivery  \
# 0               210 W. WASHINGTON ST.   97907       NaN      NaN
# 1                 120 E WASHINGTON ST   97907       Yes      NaN
# 2      160 N. MILL STREET, SUITE #102   97877       Yes      NaN
# 3    363 B SOUTH MILL STREET PO BOX 74  97877       NaN      NaN
# 4                    126 SW AVERY AVE   97333       NaN      NaN
# ..                                 ...    ...       ...      ...
# 732      2316 E PORTLAND RD SUITE C-2   97132       Yes      NaN
# 733         308 VILLA ROAD, SUITE 115   97132       Yes      Yes
# 734           1013 N. SPRINGBROOK RD.   97132       Yes      Yes
# 735                    1210 W MAIN ST   97378       Yes      NaN
# 736              950 SE SHERIDAN ROAD   97378       Yes      Yes
#
#                                        Full Address
# 0            210 W. WASHINGTON ST. , HUNTINGTON, OR
# 1              120 E WASHINGTON ST , HUNTINGTON, OR
# 2      160 N. MILL STREET, SUITE #102 , SUMPTER, OR
# 3    363 B SOUTH MILL STREET PO BOX 74, SUMPTER, OR
# 4                  126 SW AVERY AVE , CORVALLIS, OR
# ..                                              ...
# 732      2316 E PORTLAND RD SUITE C-2 , NEWBERG, OR
# 733         308 VILLA ROAD, SUITE 115 , NEWBERG, OR
# 734           1013 N. SPRINGBROOK RD. , NEWBERG, OR
# 735                   1210 W MAIN ST , SHERIDAN, OR
# 736             950 SE SHERIDAN ROAD , SHERIDAN, OR
#
# [737 rows x 8 columns]

# %%
retail_licenses_df['long'] = ""
retail_licenses_df['lat'] = ""

# %%
retail_licenses_df
# Out:
#                         TRADE NAME POSTAL CITY   COUNTY  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                         STREET ADDRESS    ZIP Med Grade Delivery  \
# 0               210 W. WASHINGTON ST.   97907       NaN      NaN
# 1                 120 E WASHINGTON ST   97907       Yes      NaN
# 2      160 N. MILL STREET, SUITE #102   97877       Yes      NaN
# 3    363 B SOUTH MILL STREET PO BOX 74  97877       NaN      NaN
# 4                    126 SW AVERY AVE   97333       NaN      NaN
# ..                                 ...    ...       ...      ...
# 732      2316 E PORTLAND RD SUITE C-2   97132       Yes      NaN
# 733         308 VILLA ROAD, SUITE 115   97132       Yes      Yes
# 734           1013 N. SPRINGBROOK RD.   97132       Yes      Yes
# 735                    1210 W MAIN ST   97378       Yes      NaN
# 736              950 SE SHERIDAN ROAD   97378       Yes      Yes
#
#                                        Full Address long lat
# 0            210 W. WASHINGTON ST. , HUNTINGTON, OR
# 1              120 E WASHINGTON ST , HUNTINGTON, OR
# 2      160 N. MILL STREET, SUITE #102 , SUMPTER, OR
# 3    363 B SOUTH MILL STREET PO BOX 74, SUMPTER, OR
# 4                  126 SW AVERY AVE , CORVALLIS, OR
# ..                                              ...  ...  ..
# 732      2316 E PORTLAND RD SUITE C-2 , NEWBERG, OR
# 733         308 VILLA ROAD, SUITE 115 , NEWBERG, OR
# 734           1013 N. SPRINGBROOK RD. , NEWBERG, OR
# 735                   1210 W MAIN ST , SHERIDAN, OR
# 736             950 SE SHERIDAN ROAD , SHERIDAN, OR
#
# [737 rows x 10 columns]

# %%
for x in range(len(retail_licenses_df)):
    try:
        geocode_result = gmaps.geocode(retail_licenses_df['Full Address'][x])
        retail_licenses_df['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        retail_licenses_df['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
retail_licenses_df.head()
# Out:
# C:\Users\Calvin Bauer\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Calvin Bauer\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#           TRADE NAME POSTAL CITY  COUNTY                     STREET ADDRESS  \
# 0           420VILLE  HUNTINGTON   BAKER             210 W. WASHINGTON ST.
# 1       HOTBOX FARMS  HUNTINGTON   BAKER               120 E WASHINGTON ST
# 2     SUMPTER NUGGET     SUMPTER   BAKER    160 N. MILL STREET, SUITE #102
# 3    THE COUGHIE POT     SUMPTER   BAKER  363 B SOUTH MILL STREET PO BOX 74
# 4  BEATNICK'S FINEST   CORVALLIS  BENTON                  126 SW AVERY AVE
#
#      ZIP Med Grade Delivery                                    Full Address  \
# 0  97907       NaN      NaN          210 W. WASHINGTON ST. , HUNTINGTON, OR
# 1  97907       Yes      NaN            120 E WASHINGTON ST , HUNTINGTON, OR
# 2  97877       Yes      NaN    160 N. MILL STREET, SUITE #102 , SUMPTER, OR
# 3  97877       NaN      NaN  363 B SOUTH MILL STREET PO BOX 74, SUMPTER, OR
# 4  97333       NaN      NaN                126 SW AVERY AVE , CORVALLIS, OR
#
#       long      lat
# 0 -117.271  44.3509
# 1 -117.266  44.3511
# 2 -118.202  44.7457
# 3 -118.202  44.7431
# 4 -123.266  44.5516

# %%
retail_licenses_df
# Out:
#                         TRADE NAME POSTAL CITY   COUNTY  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                         STREET ADDRESS    ZIP Med Grade Delivery  \
# 0               210 W. WASHINGTON ST.   97907       NaN      NaN
# 1                 120 E WASHINGTON ST   97907       Yes      NaN
# 2      160 N. MILL STREET, SUITE #102   97877       Yes      NaN
# 3    363 B SOUTH MILL STREET PO BOX 74  97877       NaN      NaN
# 4                    126 SW AVERY AVE   97333       NaN      NaN
# ..                                 ...    ...       ...      ...
# 732      2316 E PORTLAND RD SUITE C-2   97132       Yes      NaN
# 733         308 VILLA ROAD, SUITE 115   97132       Yes      Yes
# 734           1013 N. SPRINGBROOK RD.   97132       Yes      Yes
# 735                    1210 W MAIN ST   97378       Yes      NaN
# 736              950 SE SHERIDAN ROAD   97378       Yes      Yes
#
#                                        Full Address     long      lat
# 0            210 W. WASHINGTON ST. , HUNTINGTON, OR -117.271  44.3509
# 1              120 E WASHINGTON ST , HUNTINGTON, OR -117.266  44.3511
# 2      160 N. MILL STREET, SUITE #102 , SUMPTER, OR -118.202  44.7457
# 3    363 B SOUTH MILL STREET PO BOX 74, SUMPTER, OR -118.202  44.7431
# 4                  126 SW AVERY AVE , CORVALLIS, OR -123.266  44.5516
# ..                                              ...      ...      ...
# 732      2316 E PORTLAND RD SUITE C-2 , NEWBERG, OR -122.957  45.3028
# 733         308 VILLA ROAD, SUITE 115 , NEWBERG, OR -122.962  45.3026
# 734           1013 N. SPRINGBROOK RD. , NEWBERG, OR -122.947   45.307
# 735                   1210 W MAIN ST , SHERIDAN, OR -123.418  45.0975
# 736             950 SE SHERIDAN ROAD , SHERIDAN, OR -123.382   45.094
#
# [737 rows x 10 columns]

# %%
# retail_licenses_df.to_csv(r'output\storeLatLong.csv', index = False)
