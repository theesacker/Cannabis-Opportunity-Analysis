# %%
import pandas as pd

county_sales_csv = "resources/Cannabis_Sales_By_County.csv"
census_pop_csv = "resources/Census_pop.csv"
county_per_cap_income_csv = "resources/County Per capita income.csv"
retail_licenses_csv = "resources/retail-licenses.csv"
from googlemaps import Client as GoogleMaps

# gmaps = GoogleMaps('')

# %%
# county_sales_df = pd.read_csv(county_sales_csv)
# census_pop_df = pd.read_csv(census_pop_csv)
# county_per_cap_income_df = pd.read_csv(county_per_cap_income_csv)
# retail_licenses_df = pd.read_csv(retail_licenses_csv)

# %%
# oregon_city_pop = census_pop_df.loc[census_pop_df["Geographic Area"].str.endswith("Oregon"), ["Geographic Area", "Census", "2019"]].reset_index(drop=True)
# oregon_city_pop = oregon_city_pop.rename(columns={"Census": "2020"})
# oregon_city_pop

# %%
# oregon_city_pop['long'] = ""
# oregon_city_pop['lat'] = ""

# %%
# oregon_city_pop

# %%
# for x in range(len(oregon_city_pop)):
#     try:
#         geocode_result = gmaps.geocode(oregon_city_pop['Geographic Area'][x])
#         oregon_city_pop['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
#         oregon_city_pop['long'][x] = geocode_result[0]['geometry']['location']['lng']
#     except IndexError:
#         print("Address was wrong...")
#     except Exception as e:
#         print("Unexpected error occurred.", e )
# oregon_city_pop.head()

# %%
# oregon_city_pop.to_csv(r'output\cityLatLong.csv', index = False)

# %%
# retail_licenses_df

# %%
# retail_licenses_df['long'] = ""
# retail_licenses_df['lat'] = ""

# %%
# retail_licenses_df

# %%
# for x in range(len(retail_licenses_df)):
#     try:
#         geocode_result = gmaps.geocode(retail_licenses_df['Full Address'][x])
#         retail_licenses_df['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
#         retail_licenses_df['long'][x] = geocode_result[0]['geometry']['location']['lng']
#     except IndexError:
#         print("Address was wrong...")
#     except Exception as e:
#         print("Unexpected error occurred.", e )
# retail_licenses_df.head()

# %%
# retail_licenses_df

# %%
# retail_licenses_df.to_csv(r'output\storeLatLong.csv', index = False)

# %%
city_data = pd.read_csv("output\cityLatLong.csv")

# %%
city_data
# Out:
#                 Geographic Area    2020    2019        long        lat
# 0    Adair Village city, Oregon     840     874 -123.217876  44.670676
# 1            Adams city, Oregon     350     357 -118.562473  45.767354
# 2           Adrian city, Oregon     177     173 -117.071826  43.740716
# 3           Albany city, Oregon  50,158  55,338 -123.105928  44.636511
# 4            Amity city, Oregon   1,614   1,724 -123.207326  45.115672
# ..                          ...     ...     ...         ...        ...
# 235       Woodburn city, Oregon  24,080  26,273 -122.855372  45.143731
# 236   Wood Village city, Oregon   3,878   4,093 -122.418444  45.537111
# 237        Yachats city, Oregon     690     784 -124.104842  44.311231
# 238        Yamhill city, Oregon   1,024   1,169 -123.187824  45.341504
# 239       Yoncalla city, Oregon   1,047   1,096 -123.282517  43.599141
#
# [240 rows x 5 columns]

# %%
retail_licenses_data = pd.read_csv("output\storeLatLong.csv")

# %%
retail_licenses_data
# Out:
#                         TRADE NAME POSTAL CITY   COUNTY  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                         STREET ADDRESS    ZIP Med Grade Delivery  \
# 0               210 W. WASHINGTON ST.   97907       NaN      NaN
# 1                 120 E WASHINGTON ST   97907       Yes      NaN
# 2      160 N. MILL STREET, SUITE #102   97877       Yes      NaN
# ...

# %%
Retail_Map = retail_licenses_data.drop(columns=["Med Grade","Delivery", "ZIP","STREET ADDRESS"])
Retail_Map = Retail_Map.rename(columns={"TRADE NAME": "Dispensary Name"})
Retail_Map = Retail_Map.rename(str.title, axis='columns')

# %%
Retail_Map
# Out:
#                    Dispensary Name Postal City   County  \
# 0                         420VILLE  HUNTINGTON    BAKER
# 1                     HOTBOX FARMS  HUNTINGTON    BAKER
# 2                   SUMPTER NUGGET     SUMPTER    BAKER
# 3                  THE COUGHIE POT     SUMPTER    BAKER
# 4                BEATNICK'S FINEST   CORVALLIS   BENTON
# ..                             ...         ...      ...
# 732                    CANNA BROS.     NEWBERG  YAMHILL
# 733                 OASIS CANNABIS     NEWBERG  YAMHILL
# 734  WESTERN OREGON DISPENSARY INC     NEWBERG  YAMHILL
# 735                    CANNA BROS.    SHERIDAN  YAMHILL
# 736    POTTONMOUTH RETAIL CANNABIS    SHERIDAN  YAMHILL
#
#                                        Full Address        Long        Lat
# 0            210 W. WASHINGTON ST. , HUNTINGTON, OR -117.271138  44.350945
# 1              120 E WASHINGTON ST , HUNTINGTON, OR -117.266184  44.351143
# ...

# %%
Retail_Map["Postal City"] = Retail_Map["Postal City"].str.title() 
Retail_Map["Dispensary Name"] = Retail_Map["Dispensary Name"].str.title() 
Retail_Map["County"] = Retail_Map["County"].str.title() 
Retail_Map["Full Address"] = Retail_Map["Full Address"].str.title()

# %%
Retail_Map.to_csv(r'output\Retail_Map.csv', index = False)

# %%
retail_sales_csv = "output\county_dispo_data.csv"
retail_sales_df = pd.read_csv(retail_sales_csv)

# %%
retail_sales_df
# Out:
#         County  Personal Income  Population  Per capita income ($)  \
# 0    Multnomah      49399774000      812855                  60773
# 1   Washington      38527576000      601592                  64043
# 2    Clackamas      25812808000      418187                  61726
# 3         Lane      18087217000      382067                  47340
# 4       Marion      15706672000      347818                  45158
# 5    Deschutes      11159204000      197692                  56447
# 6      Jackson      10669698000      220944                  48291
# 7         Linn       5816653000      129749                  44830
# 8      Yamhill       5086605000      107100                  47494
# 9      Douglas       4698282000      110980                  42334
# 10      Benton       4534024000       93053                  48725
# 11   Josephine       3810451000       87487                  43554
# 12        Polk       3692806000       86085                  42897
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
y = retail_sales_df["Per capita income ($)"]
x = retail_sales_df["Sales per Capita"]
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
y = retail_sales_df["Dispensary Count"]
x = retail_sales_df["Sales per Capita"]
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = retail_sales_df["Personal Income"]
y = retail_sales_df["Sales"]
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = retail_sales_df["Dispensary Count"]
y = retail_sales_df["Sales"]
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = retail_sales_df["Personal Income"]
y = retail_sales_df["Population"]
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

X = retail_sales_df["County"]
Y = retail_sales_df["Per capita income ($)"]
Z = retail_sales_df["Sales per Capita"]

df = pd.DataFrame(np.c_[Y,Z,Y], index=X)
df.plot.bar()

plt.show()
